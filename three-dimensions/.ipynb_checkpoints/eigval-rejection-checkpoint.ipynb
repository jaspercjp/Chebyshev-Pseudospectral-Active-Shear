# %%
import sys
import os
sys.path.append("../core-scripts")
from zeroShearSpectrum3D import spectrum, plot_modes
import numpy as np
import matplotlib.pyplot as plt
from cheb import cheb
from scipy.linalg import eig
chebfit = np.polynomial.chebyshev.Chebyshev.fit

# %%
k,a = 1.25, 1.09
evals_low, evecs_low = spectrum(k,a,M=50)
evals_high, evecs_high = spectrum(k,a,M=100)
re_evals_low = np.real(evals_low)
re_evals_high = np.real(evals_high)
sort_idx_low = np.argsort(-re_evals_low)
re_evals_low = re_evals_low[sort_idx_low]
sort_idx_high = np.argsort(-re_evals_high)
re_evals_high = re_evals_high[sort_idx_high];
# Out:
# There are 99 finite eigenvalues
# The shape of the eigenmodes is (400, 400)
# The shape of the cleaned eigenmodes is (400, 99)
# There are 199 finite eigenvalues
# The shape of the eigenmodes is (800, 800)
# The shape of the cleaned eigenmodes is (800, 199)

# %%
n = min(len(re_evals_low), len(re_evals_high))
diffs = np.abs(re_evals_low[0:n] - re_evals_high[0:n])
# The "mode number" here only refers to how the modes are numbered
# in ascending order
plt.figure()
plt.plot(np.arange(n), diffs, marker='x')
plt.ylabel("$Re[\sigma_{low}] - Re[\sigma_{high}]$")
plt.xlabel("mode number")
plt.figure()
plt.scatter(np.arange(n), np.log(1/diffs), marker='x');
plt.ylabel("$-\log(Re[\sigma_{low}] - Re[\sigma_{high}])$")
plt.xlabel("mode number")
# Out:
# Text(0.5, 0, 'mode number')

# %%
sort_idx_low
# Out:
# array([72, 73, 74, 75, 79, 86, 98, 97, 96, 95, 94, 93, 92, 91, 90, 89, 88,
#        87, 85, 84, 82, 83, 80, 81, 78, 77, 76, 71, 70, 69, 68, 66, 67, 64,
#        65, 62, 63, 60, 61, 58, 59, 56, 57, 54, 55, 53, 52, 51, 50, 49, 48,
#        47, 46, 45, 44, 43,  2, 42, 41, 40, 39, 38, 36, 37, 35, 33, 32, 34,
#        31, 28, 27, 29, 30, 23, 24, 26, 25, 19, 20, 22, 21,  1, 15, 16, 18,
#        17, 11, 12, 14, 13,  7,  9,  8, 10,  3,  4,  6,  5,  0])

# %%
idx = sort_idx_low[0]
M=50
_, ygl_low = cheb(M)
plot_modes(idx,ygl_low,evecs_low,M)

# %%
idx = sort_idx_low[10]
print(evals_low[idx])
_, ygl = cheb(50)
plot_modes(idx, ygl, evecs_low, M=50)
# Out:
# (-1.151037001649397+0j)

# %% [markdown]
# ## Figure out analytic for $Q_{zz}$ later

# %%
# Analytical solution to the Qzz equation
n = np.array(range(50),dtype='d')
sigmas = -0.01*(np.pi**2)*n*n/4 - 1 - 0.01*(k**2)

# %%
print(np.round(sigmas,5))
print(list(np.round(re_evals_low,5)))
# Out:
# [ -1.01562  -1.0403   -1.11432  -1.23769  -1.41041  -1.63248  -1.90389
#   -2.22465  -2.59476  -3.01422  -3.48303  -4.00118  -4.56868  -5.18553
#   -5.85173  -6.56728  -7.33217  -8.14641  -9.01     -9.92294 -10.88523
#  -11.89686 -12.95785 -14.06818 -15.22786 -16.43688 -17.69526 -19.00298
#  -20.36005 -21.76647 -23.22223 -24.72735 -26.28181 -27.88562 -29.53878
#  -31.24129 -32.99314 -34.79435 -36.6449  -38.5448  -40.49404 -42.49264
#  -44.54058 -46.63787 -48.78451 -50.9805  -53.22583 -55.52052 -57.86455
#  -60.25793]
# [0.05158, -0.02159, -0.14458, -0.31685, -0.53817, -0.80747, -1.01562, -1.024, -1.05224, -1.09779, -1.15104, -1.23796, -1.41205, -1.50104, -1.63721, -1.88709, -1.9409, -2.22149, -2.39588, -2.59346, -2.91205, -3.01376, -3.47871, -3.48305, -4.00159, -4.09504, -4.56939, -4.76084, -5.18654, -5.47603, -5.85303, -6.24056, -6.56891, -7.05438, -7.33421, -7.91743, -8.14899, -8.82958, -9.01335, -9.79057, -9.92759, -10.79959, -10.89248, -11.85344, -11.91123, -12.941, -12.99493, -14.06011, -14.14606, -15.22309, -15.35272, -16.43424, -16.60706, -17.69058, -17.9037, -18.98668, -19.28125, -19.30218, -20.38823, -20.67275, -21.74666, -22.31399, -23.14944, -23.40261, -24.10128, -26.53411, -27.16669, -27.62275, -28.11002, -32.24644, -32.33589, -33.28972, -33.33531, -42.21988, -42.64638, -43.30901, -43.62315, -56.41685, -56.46162, -57.40081, -57.55096, -82.76327, -86.74205, -87.27181, -87.83159, -88.26404, -137.63215, -137.82947, -138.62754, -138.91917, -310.32103, -311.41091, -311.50641, -312.50543, -821.8346, -822.63963, -822.8347, -823.72953, -2630.54858]

# %%
idx=sort_idx_low[0]
print(evals_low[idx])
plot_modes(idx,ygl,evecs_low,M=50)
# Out:
# (0.051583169829662996-0j)

# %% [markdown]
# # Scan over activity values

# %%
al,ar,an = 0.01, 5, 30
kl,kr,kn = 0.01, 20, 30
acts = np.linspace(al,ar,an)
ks = np.linspace(kl,kr,kn)
for i in range(len(acts)):
    print("Computing for {}/{} activity value".format(i+1,len(acts)))
    if not os.path.exists("data/manual-a-scan-1/M_50/a_{}/".format(i)):
        os.mkdir("data/manual-a-scan-1/M_50/a_{}/".format(i))
        
    if not os.path.exists("data/manual-a-scan-1/M_100/a_{}/".format(i)):
        os.mkdir("data/manual-a-scan-1/M_100/a_{}/".format(i))
        
    for j in range(len(ks)):
        evals_low,_ = spectrum(ks[j],acts[i],M=50)
        evals_high,_ = spectrum(ks[j],acts[i],M=100)
        np.savetxt("data/manual-a-scan-1/M_50/a_{}/k_{}".format(i,j),evals_low,delimiter=',')
        np.savetxt("data/manual-a-scan-1/M_100/a_{}/k_{}".format(i,j),evals_high,delimiter=',')
# Out:
# 0/30 activity values computed
# There are 99 finite eigenvalues
# The shape of the eigenmodes is (400, 400)
# The shape of the cleaned eigenmodes is (400, 99)
# There are 199 finite eigenvalues
# The shape of the eigenmodes is (800, 800)
# The shape of the cleaned eigenmodes is (800, 199)
# There are 99 finite eigenvalues
# The shape of the eigenmodes is (400, 400)
# The shape of the cleaned eigenmodes is (400, 99)
# There are 199 finite eigenvalues
# The shape of the eigenmodes is (800, 800)
# The shape of the cleaned eigenmodes is (800, 199)
# There are 99 finite eigenvalues
# The shape of the eigenmodes is (400, 400)
# The shape of the cleaned eigenmodes is (400, 99)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 15
#      13 for j in range(len(ks)):
#      14     evals_low,_ = spectrum(ks[j],acts[i],M=50)
# ---> 15     evals_high,_ = spectrum(ks[j],acts[i],M=100)
#      16     np.savetxt("data/manual-a-scan-1/M_50/a_{}/k_{}".format(i,j),evals_low,delimiter=',')
#      17     np.savetxt("data/manual-a-scan-1/M_100/a_{}/k_{}".format(i,j),evals_high,delimiter=',')
#
# File /mnt/c/users/jaspe/activematter/three-dimensions/../core-scripts/zeroShearSpectrum3D.py:155, in spectrum(kx, a, _ell_over_W_squared, M)
#     152 RHS[7*M]   = np.zeros(8*M,dtype='D')
#     153 RHS[8*M-1] = np.zeros(8*M,dtype='D')
# --> 155 _spec = eig(LHS,RHS,left=0,right=1)
#     157 _eig_list = _spec[0]
#     158 finite_idx = np.where(np.isfinite(_eig_list))[0]
#
# File ~/anaconda3/envs/dedalus2/lib/python3.11/site-packages/scipy/linalg/_decomp.py:225, in eig(a, b, left, right, overwrite_a, overwrite_b, check_finite, homogeneous_eigvals)
#     223     if b1.shape != a1.shape:
#     224         raise ValueError('a and b must have the same shape')
# --> 225     return _geneig(a1, b1, left, right, overwrite_a, overwrite_b,
#     226                    homogeneous_eigvals)
#     228 geev, geev_lwork = get_lapack_funcs(('geev', 'geev_lwork'), (a1,))
#     229 compute_vl, compute_vr = left, right
#
# File ~/anaconda3/envs/dedalus2/lib/python3.11/site-packages/scipy/linalg/_decomp.py:82, in _geneig(a1, b1, left, right, overwrite_a, overwrite_b, homogeneous_eigvals)
#      80 lwork = res[-2][0].real.astype(numpy.int_)
#      81 if ggev.typecode in 'cz':
# ---> 82     alpha, beta, vl, vr, work, info = ggev(a1, b1, cvl, cvr, lwork,
#      83                                            overwrite_a, overwrite_b)
#      84     w = _make_eigvals(alpha, beta, homogeneous_eigvals)
#      85 else:
#
# KeyboardInterrupt:

# %%
test = np.loadtxt("data/manual-a-scan-1/M_100/a_0/k_0",dtype=np.complex128)

# %%
test
# Out:
# array([-8.50245442e+02+0.00000000e+00j, -4.61118522e+03+0.00000000e+00j,
#        -1.90235474e+02+0.00000000e+00j, -5.13142737e+03+1.82440944e-15j,
#        -5.12713005e+03+1.81507203e-15j, -1.36532121e+04+3.88839501e-17j,
#        -1.36495240e+04-2.29563717e-16j, -1.36532221e+04+1.65482408e-11j,
#        -1.36495336e+04-1.70691891e-11j, -5.12714005e+03+2.96209033e-12j,
#        -5.13143696e+03-3.01067057e-12j, -1.39747216e+03-9.00394266e-12j,
#        -1.39595301e+03-1.12888784e-11j, -2.24475884e+03-1.45629897e-11j,
#        -2.24355115e+03-1.50333773e-11j, -2.24476884e+03-4.78276125e-12j,
#        -2.24356076e+03+4.03518504e-12j, -1.39596301e+03-9.28800997e-12j,
#        -1.39748175e+03+7.88579733e-12j, -6.49407547e+02-1.02340433e-12j,
#        -6.48554810e+02-9.44271491e-12j, -8.86120547e+02+3.75172111e-12j,
#        -8.85473818e+02-6.35751414e-12j, -8.86130549e+02+1.05951168e-11j,
#        -8.85483400e+02-9.04905689e-12j, -6.48564809e+02-1.50758138e-11j,
#        -6.49417129e+02+1.20043998e-11j, -3.79107095e+02+1.86329211e-12j,
#        -3.78519367e+02-9.34303302e-12j, -4.76318258e+02+9.60987816e-12j,
#        -4.75896237e+02-7.55995456e-12j, -4.76328259e+02+1.66621610e-11j,
#        -4.75905806e+02-1.40108882e-11j, -3.78529366e+02-1.60968873e-11j,
#        -3.79116661e+02+1.51105642e-11j, -2.51999747e+02+3.54205398e-12j,
#        -2.51537629e+02-8.51607477e-12j, -3.00890490e+02+8.73248885e-12j,
#        -3.00584780e+02-7.04638428e-12j, -3.00900491e+02+1.49420480e-11j,
#        -3.00594331e+02-1.24785545e-11j, -2.51547628e+02-1.42603095e-11j,
#        -2.52009289e+02+1.32528534e-11j, -1.82546342e+02+1.98807072e-12j,
